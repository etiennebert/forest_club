# %%
import os
import plotly.graph_objects as go
import plotly.express as px
import plotly.colors
import pandas as pd
import numpy as np

# %%
source_path = os.path.join("C:/Users/etber/OneDrive - Massachusetts Institute of Technology/Documents/Deforestation_Nature/2. MRIO/")
folder = os.path.join(source_path,'Visualisation','2. Sankeys','3_Jupyter_files')
file = '3_Jupyter_Sankey_BRA.xlsx'
figures_folder = os.path.join(folder,'Figure 1')

# %%
dataset_df = pd.read_excel(os.path.join(folder,file))
dataset_df.head()
# Out:
#    RecordID  Source  Target       Value    Nature             Link Color  \
# 0         1      14      53   15.474515  Indirect  rgb(42, 87, 131, 0.8)
# 1         2      14      54   13.621615  Indirect  rgb(42, 87, 131, 0.8)
# 2         3      14      59   70.332701  Indirect  rgb(42, 87, 131, 0.8)
# 3         4      14      60   20.692673  Indirect  rgb(42, 87, 131, 0.8)
# 4         5      14      61  336.270477  Indirect  rgb(42, 87, 131, 0.8)
#
#      Color                Node, Label
# 0  #e5243B                     Brazil
# 1  #a21942  Australia and New Zealand
# 2  #a21942                     Brazil
# 3  #a21942                  Caribbean
# 4  #a21942            Central America

# %%
data_trace = dict(
    type='sankey',
    arrangement='perpendicular',
    domain = dict(
      x =  [0,1],
      y =  [0,1]
    ),
    orientation = "h",
    valueformat = ".0f",
    node = dict(
      pad = 50,
      thickness = 25,
      line = dict(
        color = "black",
        width = 0
      ),
      label =  dataset_df['Node, Label'].dropna(axis=0, how='any'),
      color = dataset_df['Color'].dropna(axis=0, how='any'),
        #x = dataset_df['Node, X'].dropna(axis=0, how='any'), 
        #y = dataset_df['Node, Y'].dropna(axis=0, how='any'),
        #offsetHorizontal: -50,
    ),
    link = dict(
      source = dataset_df['Source'].dropna(axis=0, how='any'),
      target = dataset_df['Target'].dropna(axis=0, how='any'),
      value = dataset_df['Value'].dropna(axis=0, how='any'),
      color = dataset_df['Link Color'].dropna(axis=0, how='any'),
  )
)

layout =  dict(
    #title = "Transfer of points for the SDGs 8.4.1 and 12.2.1 by area of origin, transfer and destination",
    height = 2480/3,
    width= 1754,
    #scale = 1,
    font = dict(
      size = 15,
        weight = 'bold'
    ),    
)

fig = go.Figure(data=[data_trace], layout=layout)
fig.show()
fig.write_image("figure_1_sankey_COD.png", engine="kaleido")
# Out:
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# Cell In[68], line 44
#      42 fig = go.Figure(data=[data_trace], layout=layout)
#      43 fig.show()
# ---> 44 fig.write_image("figure_1_sankey_COD.png", engine="kaleido")
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\plotly\basedatatypes.py:3835, in BaseFigure.write_image(self, *args, **kwargs)
#    3775 """
#    3776 Convert a figure to a static image and write it to a file or writeable
#    3777 object
#    (...)
#    3831 None
#    3832 """
#    3833 import plotly.io as pio
# -> 3835 return pio.write_image(self, *args, **kwargs)
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\plotly\io\_kaleido.py:266, in write_image(fig, file, format, scale, width, height, validate, engine)
#     250             raise ValueError(
#     251                 """
#     252 Cannot infer image type from output path '{file}'.
#    (...)
#     260                 )
#     261             )
#     263     # Request image
#     264     # -------------
#     265     # Do this first so we don't create a file if image conversion fails
# --> 266     img_data = to_image(
#     267         fig,
#     268         format=format,
#     269         scale=scale,
#     270         width=width,
#     271         height=height,
#     272         validate=validate,
#     273         engine=engine,
#     274     )
#     276     # Open file
#     277     # ---------
#     278     if path is None:
#     279         # We previously failed to make sense of `file` as a pathlib object.
#     280         # Attempt to write to `file` as an open file descriptor.
#
# File ~\AppData\Local\anaconda3\Lib\site-packages\plotly\io\_kaleido.py:132, in to_image(fig, format, width, height, scale, validate, engine)
#     130     # Raise informative error message if Kaleido is not installed
#     131     if scope is None:
# --> 132         raise ValueError(
#     133             """
#     134 Image export using the "kaleido" engine requires the kaleido package,
#     135 which can be installed using pip:
#     136     $ pip install -U kaleido
#     137 """
#     138         )
#     140     # Validate figure
#     141     # ---------------
#     142     fig_dict = validate_coerce_fig_to_dict(fig, validate)
#
# ValueError:
# Image export using the "kaleido" engine requires the kaleido package,
# which can be installed using pip:
#     $ pip install -U kaleido
